# %% [markdown]
# # ⚡ XR Foundation Model (XRFM) — Free Google Colab GPU Training
#
# Train your custom language model in **15 seconds** using Google Colab's Free T4 GPU!

# %%
# 1. Check GPU availability
# !nvidia-smi

# %%
# 2. Clone repository & install dependencies
# !git clone https://github.com/ahmadrrrtx/xr-foundation-model.git
# %cd xr-foundation-model
# !pip install -e .

# %%
# 3. Run high-speed GPU custom model training (500 steps in ~15s!)
# !python scripts/train_custom_model.py --max_steps 500 --batch_size 16

# %%
# 4. Commit and push trained checkpoint back to GitHub
# !git config --global user.email "your-email@example.com"
# !git config --global user.name "ahmadrrrtx"
# !git add checkpoints/ tokenizer/vocab.json
# !git commit -m "feat: add GPU trained XRFM model checkpoint"
# !git push origin main
